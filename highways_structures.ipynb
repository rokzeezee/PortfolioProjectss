# %% [markdown]
# <a href="https://colab.research.google.com/github/rokzeezee/PortfolioProjectss/blob/main/highways_structures.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
che_485 = pd.read_csv("/content/CHE 485_22 Area 4 bridges1.csv")
che_485
# Out:
#     Structure Key                                     Sub  type   \
# 0              NaN  Accommodation Access Overbridge - Overbridge
# 1        STR_11634               Highway Overbridge - Overbridge
# 2        STR_11635               Highway Overbridge - Overbridge
# 3        STR_11636           Bridleway Underbridge - Underbridge
# 4        STR_11637             Highway Underbridge - Underbridge
# ..             ...                                           ...
# 501      STR_25529               Highway Overbridge - Overbridge
# 502      STR_40210               Highway Overbridge - Overbridge
# 503      STR_40212               Highway Overbridge - Overbridge
# 504       STR_1261                           Highways Overbridge
# 505       STR_1308                           Highways Overbridge
#
#                          Structure Name  Constructed Next Inspection  \
# 0                     Holmbush Bridleway         NaN             NaN
# ...

# %%
 che_485_df= che_485 [['Structure Key ', 'Sub  type ', 'Structure Name ', #'Constructed',
       #'Next Inspection', 'Before Oct 2023', 'Before Mar 2024', 
 'SI Required',
       'Equipment Y/N', #'Hanging  Supports ', 'Utilities',
       #'Side/Soffit Mounted', 'Lighting Column', 'Street Furniture',
 
       #'Comments', 'Inspected'
]]

# %%
che_485_df
# Out:
#     Structure Key                                     Sub  type   \
# 0              NaN  Accommodation Access Overbridge - Overbridge
# 1        STR_11634               Highway Overbridge - Overbridge
# 2        STR_11635               Highway Overbridge - Overbridge
# 3        STR_11636           Bridleway Underbridge - Underbridge
# 4        STR_11637             Highway Underbridge - Underbridge
# ..             ...                                           ...
# 501      STR_25529               Highway Overbridge - Overbridge
# 502      STR_40210               Highway Overbridge - Overbridge
# 503      STR_40212               Highway Overbridge - Overbridge
# 504       STR_1261                           Highways Overbridge
# 505       STR_1308                           Highways Overbridge
#
#                          Structure Name  SI Required Equipment Y/N
# 0                     Holmbush Bridleway         NaN             N
# ...

# %%
che_485_df.to_csv("che_485_SI.csv" ,index=False)

# %%
che_485.describe().T
# Out:
#                     count unique                              top freq
# Structure Key         505    486                         STR_9147    2
# Sub  type             506     13  Highway Overbridge - Overbridge  191
# Structure Name        506    486               East Cliff Viaduct    2
# Constructed           500     74                       01/01/1993   50
# Next Inspection       500    237                       01/09/2022   13
# Before Oct 2023       500      2                                N  255
# Before Mar 2024       129      3                                Y   71
# SI Required           500      2                                N  476
# Equipment Y/N         506      2                                N  377
# Hanging  Supports     501      2                                N  440
# Utilities             501      3                                N  447
# Side/Soffit Mounted   499      3                                N  388
# ...

# %%
# Nan  in some of the inpsections means we didnt find any report to back it up . but for the execrcise we  address it as 0(N)

che_485_df[[i for i in che_485_df.columns if che_485_df[i].isnull().sum()]].isnull().sum()
# Out:
# Structure Key     1
# SI Required       6
# dtype: int64

# %%
che_485_df["SI Required"].value_counts
# Out:
# <bound method IndexOpsMixin.value_counts of 0      NaN
# 1        N
# 2        Y
# 3        N
# 4        N
#       ...
# 501      Y
# 502    NaN
# 503    NaN
# 504      Y
# 505      N
# Name: SI Required, Length: 506, dtype: object>

# %%
che_485_df.isnull().sum()
# Out:
# Structure Key      1
# Sub  type          0
# Structure Name     0
# SI Required        6
# Equipment Y/N      0
# dtype: int64

# %%
che_485_df.iloc[:,3]
# Out:
# 0      NaN
# 1        N
# 2        Y
# 3        N
# 4        N
#       ...
# 501      Y
# 502    NaN
# 503    NaN
# 504      Y
# 505      N
# Name: SI Required, Length: 506, dtype: object

# %%
che_485_df.groupby("SI Required").describe()
# Out:
#             Structure Key                         Sub  type          \
#                      count unique        top freq      count unique
# SI Required
# N                      476    461  STR_17074    2        476     13
# Y                       24     24  STR_11635    1         24      4
#
#                                                   Structure Name          \
#                                          top freq           count unique
# SI Required
# N            Highway Overbridge - Overbridge  173             476    460
# Y            Highway Overbridge - Overbridge   16              24     24
#
#                                     Equipment Y/N
#                            top freq         count unique top freq
# SI Required
# N              Patcham Viaduct    2           476      2   N  371
# Y            Patching Junction    1            24      1   Y   24

# %%
che_485_df["SI Required_Num "] = che_485_df["SI Required"].apply(lambda x : 1 if x == "Y" else 0)
# Out:
# <ipython-input-38-b68811a80cea>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   che_485_df["SI Required_Num "] = che_485_df["SI Required"].apply(lambda x : 1 if x == "Y" else 0)

# %%
che_485_df.corr()
# Out:
# <ipython-input-40-ba1a358e458e>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   che_485_df.corr()
#                   SI Required_Num
# SI Required_Num                1.0

# %%
cor_mat=che_485_df.corr()
fig,ax=plt.subplots(figsize=(9,9))
sns.heatmap(cor_mat,annot=True,linewidths=0.5,fmt=".3f" , cmap = "Blues_r")
# Out:
# <ipython-input-44-1d1eff02d763>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor_mat=che_485_df.corr()
# <Axes: >

# %%
che_485_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 506 entries, 0 to 505
# Data columns (total 6 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Structure Key     505 non-null    object
#  1   Sub  type         506 non-null    object
#  2   Structure Name    506 non-null    object
#  3   SI Required       500 non-null    object
#  4   Equipment Y/N     506 non-null    object
#  5   SI Required_Num   506 non-null    int64
# dtypes: int64(1), object(5)
# memory usage: 23.8+ KB
