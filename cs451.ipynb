# %% [markdown]
# <a href="https://colab.research.google.com/github/rokzeezee/PandasYouTubeSeries/blob/main/cs451.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd 
pd.set_option("display.max_rows" , 10)
pd.set_option("display.max_columns" , 30)
import matplotlib.pyplot as plt

# %%
CS451= pd.read_excel("/content/CS451_2023-24_Area_4_Programme & Tracker_ updated.xlsx")

# %%
CS451
# Out:
#     Unnamed: 0 Structure Key       Structure No           Structure Name  \
# 0            0     STR_11633      /A27//47.00//       Holmbush Bridleway
# 1            1     STR_11634     /A27//47.00//1       Holmbush Slip Road
# 2            2     STR_12271      /A21//34.20//    Morley Road I/C North
# 3            3     STR_12272      /A21//34.30//    Morley Road I/C South
# 4            4     STR_12279      /A21//38.00//               Leigh Road
# ..         ...           ...                ...                      ...
# 88          88      STR_9396     /A27//49.50/C/  Adur Slip Vdct N. 8-14e
# 89          89      STR_9397     /A27//49.60/C/  Adur Slip Vdct S. 6-13e
# 90          90      STR_9399      /A27//71.00//         Fitzalan Arundel
# 91          91      STR_9400  /A259//110.40/R/1        Hunting Close R/W
# 92          92      STR_9417   /A259//110.10/R/          Timber Yard R/W
#
#     Road  Kilometerage            Structure Type  \
# ...

# %%
CS451.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      93 non-null     int64
#  1   Structure Key                   93 non-null     object
#  2   Structure No                    93 non-null     object
#  3   Structure Name                  93 non-null     object
#  4   Road                            93 non-null     object
#  5   Kilometerage                    93 non-null     float64
#  6   Structure Type                  93 non-null     object
#  7   Subtype                         86 non-null     object
#  8   Status                          93 non-null     object
#  9   Date Commissioned               93 non-null     datetime64[ns]
#  10  Overall Length_x                86 non-null     float64
#  11  Width                           86 non-null     float64
# ...

# %%
CS451['Asset CPI Average']=CS451['Asset CPI Average'].round(2)

# %%
CS451['Asset CPI Critical']=CS451['Asset CPI Critical'].round(2)

# %%
CS451
# Out:
#     Unnamed: 0 Structure Key       Structure No           Structure Name  \
# 0            0     STR_11633      /A27//47.00//       Holmbush Bridleway
# 1            1     STR_11634     /A27//47.00//1       Holmbush Slip Road
# 2            2     STR_12271      /A21//34.20//    Morley Road I/C North
# 3            3     STR_12272      /A21//34.30//    Morley Road I/C South
# 4            4     STR_12279      /A21//38.00//               Leigh Road
# ..         ...           ...                ...                      ...
# 88          88      STR_9396     /A27//49.50/C/  Adur Slip Vdct N. 8-14e
# 89          89      STR_9397     /A27//49.60/C/  Adur Slip Vdct S. 6-13e
# 90          90      STR_9399      /A27//71.00//         Fitzalan Arundel
# 91          91      STR_9400  /A259//110.40/R/1        Hunting Close R/W
# 92          92      STR_9417   /A259//110.10/R/          Timber Yard R/W
#
#     Road  Kilometerage            Structure Type  \
# ...

# %%
CS451.to_excel("CS451_UPDATED.xlsx")

# %%
CS451.set_index("Structure Key").head(3)
# Out:
#                Unnamed: 0    Structure No         Structure Name Road  \
# Structure Key
# STR_11633               0   /A27//47.00//     Holmbush Bridleway  A27
# STR_11634               1  /A27//47.00//1     Holmbush Slip Road  A27
# STR_12271               2   /A21//34.20//  Morley Road I/C North  A21
#
#                Kilometerage            Structure Type  \
# Structure Key
# STR_11633              47.0  Bridge And Large Culvert
# STR_11634              47.0  Bridge And Large Culvert
# STR_12271              34.5  Bridge And Large Culvert
#
#                                                     Subtype       Status  \
# Structure Key
# STR_11633      Accommodation Access Overbridge - Overbridge  Constructed
# STR_11634                   Highway Overbridge - Overbridge  Constructed
# STR_12271                   Highway Overbridge - Overbridge  Constructed
#
#               Date Commissioned  Overall Length_x  Width  Width.1  \
# Structure Key
# ...

# %%
CS451.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 93 entries, 0 to 92
# Data columns (total 28 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   Unnamed: 0                      93 non-null     int64
#  1   Structure Key                   93 non-null     object
#  2   Structure No                    93 non-null     object
#  3   Structure Name                  93 non-null     object
#  4   Road                            93 non-null     object
#  5   Kilometerage                    93 non-null     float64
#  6   Structure Type                  93 non-null     object
#  7   Subtype                         86 non-null     object
#  8   Status                          93 non-null     object
#  9   Date Commissioned               93 non-null     datetime64[ns]
#  10  Overall Length_x                86 non-null     float64
#  11  Width                           86 non-null     float64
# ...

# %%
CS451.columns
# Out:
# Index(['Unnamed: 0', 'Structure Key', 'Structure No', 'Structure Name', 'Road',
#        'Kilometerage', 'Structure Type', 'Subtype', 'Status',
#        'Date Commissioned', 'Overall Length_x', 'Width', 'Width.1',
#        'Date Calculated', 'Asset CPI Average', 'Asset CPI Critical',
#        'Overall Condition of Structure', 'Crosses', 'Easting', 'Northing',
#        'Review\nIAMIS', 'ReviewLatestAssessment', 'Review LatestInspections',
#        'Carry Out RiskAppraisal', 'CompleteAppendix  B', 'Check', 'Submit',
#        'Date  of  NH\nAcceptance'],
#       dtype='object')

# %%
df=CS451[[#'Unnamed: 0', 
  'Structure Key', #'Structure No', 
  'Structure Name', #'Road',
       #'Kilometerage', 
       'Structure Type', #'Subtype', 'Status',
       #'Date Commissioned', 
  #'Overall Length_x', 'Width', #'Width.1',
       #'Date Calculated', 
  'Asset CPI Average', 'Asset CPI Critical',
       'Overall Condition of Structure', #'Crosses', 
  #'Easting', 'Northing',
       #'Review\nIAMIS', 'ReviewLatestAssessment', 'Review LatestInspections',
       #'Carry Out RiskAppraisal', 'CompleteAppendix  B', 'Check', 'Submit',
       #'Date  of  NH\nAcceptance'
  ]].copy()

# %%
df=df.set_index("Structure Key")

# %%
df.head()
# Out:
#                       Structure Name            Structure Type  \
# Structure Key
# STR_11633         Holmbush Bridleway  Bridge And Large Culvert
# STR_11634         Holmbush Slip Road  Bridge And Large Culvert
# STR_12271      Morley Road I/C North  Bridge And Large Culvert
# STR_12272      Morley Road I/C South  Bridge And Large Culvert
# STR_12279                 Leigh Road  Bridge And Large Culvert
#
#                Asset CPI Average  Asset CPI Critical  \
# Structure Key
# STR_11633                  92.78               80.58
# STR_11634                  92.87               81.00
# STR_12271                  88.36               58.00
# STR_12272                  88.59               52.92
# STR_12279                  89.72               79.94
#
#               Overall Condition of Structure
# Structure Key
# STR_11633                                  G
# STR_11634                                  F
# STR_12271                                  G
# ...

# %%
df.iloc[10]
df.loc["STR_9147"]
# Out:
# Structure Name                          East Cliff Viaduct
# Structure Type                    Bridge And Large Culvert
# Asset CPI Average                                    82.78
# Asset CPI Critical                                    31.0
# Overall Condition of Structure                           F
# Name: STR_9147, dtype: object

# %%
df.plot(kind = "line", xlabel = "Structure key",ylabel =" Current condition of structure " ,figsize= (8,4),
        title = " CS 451 _2023-24_Programme & Tracker ")
plt.savefig("line.png")
plt.show()

# %%
df_pivot=df[df.index.isin(['STR_9130' , "STR_9110" , "STR_9147"])]

# %%
df_pivot.plot(kind = "bar"   ,xlabel= "Structure key",ylabel ="Inspectors Rating" ,figsize= (8,4),
        title = " CS 451 _2023-24_Programme & Tracker ") 


plt.tight_layout()

plt.savefig("bar.png")

plt.show()
